# %%
import scipy as sp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from importSleepAccel import import_sleep_accel

# %%
accel, hr, stage = import_sleep_accel("../Data/SleepAccel", "3997827", epoch_length=30)

# %%
accel = np.array(accel)

accel.shape
# Out:
# (1015, 3, 1490)

# %%
n = 500
x = accel[n-1:n+1].flatten()
x = x[:1000]
print(stage[n])
plt.plot(x)
# Out:
# 5
